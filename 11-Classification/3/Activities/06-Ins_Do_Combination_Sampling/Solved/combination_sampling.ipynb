# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import make_blobs
from collections import Counter

# %%
# Generate imbalanced dataset
X, y = make_blobs(n_samples = [600,60], random_state=1, cluster_std=5)

plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
# Normal train-test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
Counter(y_train)
# Out:
# Counter({0: 451, 1: 44})

# %%
# SMOTE oversampling
from imblearn.over_sampling import SMOTE
from collections import Counter

X_resampled, y_resampled = SMOTE(random_state=1, sampling_strategy=1.0).fit_resample(X_train, y_train)
Counter(y_resampled)
# Out:
# Counter({0: 451, 1: 451})

# %%
plt.scatter(X_resampled[:, 0], X_resampled[:, 1], c=y_resampled)

# %%
#SMOTEENN combination sampling
from imblearn.combine import SMOTEENN

sm = SMOTEENN(random_state=1)
X_resampled, y_resampled = sm.fit_resample(X_train, y_train)
Counter(y_resampled)
# Out:
# Counter({0: 330, 1: 361})

# %%
plt.scatter(X_resampled[:, 0], X_resampled[:, 1], c=y_resampled)

# %%
# Logistic regression using random combination sampled data
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix

y_pred = model.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[126,  23],
#        [  1,  15]], dtype=int64)

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced

print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.99      0.85      0.94      0.91      0.89      0.79       149
#           1       0.39      0.94      0.85      0.56      0.89      0.80        16
#
# avg / total       0.93      0.85      0.93      0.88      0.89      0.79       165

# %%
# Let's try without any resampling

# Logistic regression using random combination sampled data
model_no_sampling = LogisticRegression(solver='lbfgs', random_state=1)
model_no_sampling.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=1)

# %%
y_pred = model_no_sampling.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[146,   3],
#        [  9,   7]], dtype=int64)

# %%
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.94      0.98      0.44      0.96      0.65      0.45       149
#           1       0.70      0.44      0.98      0.54      0.65      0.41        16
#
# avg / total       0.92      0.93      0.49      0.92      0.65      0.45       165
